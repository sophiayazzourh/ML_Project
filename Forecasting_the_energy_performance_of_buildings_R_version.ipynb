# %% [markdown]
# # Forecasting_the_energy_performance_of_buildings_R_version

# %%
library(gmodels)
library(ggplot2)
library(GGally)
# Out:
# Warning message:
# "package 'GGally' was built under R version 4.0.3"
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %%
data<- read.csv('./DataEnergy-Students.csv')

# %%
head(data)
# Out:
#   Relative.compactness Surface.area Wall.area Roof.area Overall.height
# 1 0.9829276            530.4900     306.4846  112.0027  7
# 2 0.9835473            519.8724     299.7763  110.0480  7
# 3 0.9794535            516.1912     303.3744  106.4084  7
# 4 0.9777325            518.9241     292.8122  113.0559  7
# 5 0.9030294            552.9689     316.2361  118.3664  7
# 6 0.8909102            558.6037     314.9162  121.8437  7
#   orientation Glazing.area  Glazing.area.distr Load     Energy.efficiency
# 1 North        1.609490e-02 0                  34.26394 C
# 2 East        -9.386813e-03 0                  34.58975 C
# 3 South       -6.974937e-04 0                  38.77805 C
# 4 West         9.554434e-06 0                  37.94781 C
# 5 North       -6.592326e-03 0                  47.67586 D
# 6 East        -1.612145e-02 0                  41.90847 D

# %%
summary(data)
# Out:
#  Relative.compactness  Surface.area     Wall.area       Roof.area
#  Min.   :0.6125       Min.   :501.4   Min.   :234.3   Min.   :105.3
#  1st Qu.:0.6779       1st Qu.:598.7   1st Qu.:291.8   1st Qu.:137.4
#  Median :0.7517       Median :673.1   Median :315.8   Median :183.3
#  Mean   :0.7645       Mean   :671.3   Mean   :318.3   Mean   :176.5
#  3rd Qu.:0.8350       3rd Qu.:744.6   3rd Qu.:343.0   3rd Qu.:220.5
#  Max.   :0.9912       Max.   :826.0   Max.   :425.8   Max.   :225.8
#  Overall.height orientation         Glazing.area      Glazing.area.distr
#  Min.   :3.50   Length:768         Min.   :-0.02401   Min.   :0.000
#  1st Qu.:3.50   Class :character   1st Qu.: 0.10306   1st Qu.:1.750
#  Median :5.25   Mode  :character   Median : 0.24752   Median :3.000
#  Mean   :5.25                      Mean   : 0.23435   Mean   :2.812
#  3rd Qu.:7.00                      3rd Qu.: 0.39119   3rd Qu.:4.000
#  Max.   :7.00                      Max.   : 0.42702   Max.   :5.000
# ...

# %%
names(data)[9]<-"Energy"

# %%
plot(table(data$Energy.efficiency))
# Out:
# plot without title

# %%
table(data$Energy.efficiency, data$orientation)
# Out:
#
#     East North South West
#   A   56    56    56   56
#   B   30    30    30   30
#   C   13    12    13   12
#   D   19    19    20   19
#   E   28    27    26   27
#   F   28    29    30   28
#   G   18    19    17   20

# %%
ggplot(data, aes(x=Energy.efficiency, y=Surface.area)) + 
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data, aes(x=Energy.efficiency, y=Relative.compactness)) + 
  geom_boxplot()
# Out:
# plot without title

# %%
# Correlation plot
ggcorr(data, palette = "RdBu", label = TRUE)
# Out:
# Warning message in ggcorr(data, palette = "RdBu", label = TRUE):
# "data in column(s) 'orientation', 'Energy.efficiency' are not numeric and were ignored"
# plot without title

# %%
ggpairs(data)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# ...
